# %%
# 替换为你的 Rails 项目路径
RAILS_ROOT = "/Users/xxx/your-rails-project"
require "#{RAILS_ROOT}/config/environment"

# 测试 Rails 核心功能
puts "Rails 版本：#{Rails.version}"
puts "当前环境：#{Rails.env}"
# 假设你有 User 模型，测试 ActiveRecord
puts "用户总数：#{User.count}" if defined?(User)

# %% [markdown]
# # 替换为你的 Rails 项目路径
# RAILS_ROOT = "/Users/xxx/your-rails-project"
# require "#{RAILS_ROOT}/config/environment"
#
# # 测试 Rails 核心功能
# puts "Rails 版本：#{Rails.version}"
# puts "当前环境：#{Rails.env}"
# # 假设你有 User 模型，测试 ActiveRecord
# puts "用户总数：#{User.count}" if defined?(User)

# %%
1.设计风格：采用极简主义设计，以内容为中心，减少视觉装饰
2.布局结构：清晰的分类组织，层次分明
3.色彩方案：使用中性色调，确保内容可读性
4.排版：简洁易读的字体，整齐的排版
5.交互体验：平滑的滚动效果，便捷的导航
